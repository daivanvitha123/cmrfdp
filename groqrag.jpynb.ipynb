# %%
pip install llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.3 MB/s eta 0:00:00
# ...

# %%
pip install llama-Index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.7/261.7 kB 14.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 21.7 MB/s eta 0:00:00
# ...

# %%
from llama_index.llms.groq import Groq

# %%
GROQ_API_KEY="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"

# %%
pip install --upgrade llama-index-llms-groq

# %%
llm=Groq(model="llama3-70b-8192",api_key = "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")

# %%
response=llm.complete("Explain the importance of low latency LLMs")

# %%
print(response)
# Out:
# Low-latency Large Language Models (LLMs) are crucial in various applications where real-time or near-real-time processing is essential. Here are some reasons why low-latency LLMs are important:
#
# 1. **Interactive Systems**: In interactive systems like chatbots, virtual assistants, or conversational interfaces, low-latency LLMs enable rapid response times, making the interaction feel more natural and engaging. Users expect quick responses, and high latency can lead to frustration and abandonment.
# 2. **Real-time Decision Making**: In applications like autonomous vehicles, medical diagnosis, or financial trading, low-latency LLMs can provide critical insights and decisions in real-time, enabling swift action and minimizing the risk of errors or accidents.
# ...

# %%
from llama_index.core.llms import ChatMessage
messages = [
    ChatMessage(
        role="system",content="you are pirate with a colorful personality"
    ),
    ChatMessage(role="user",content="what is god"),
]
resp = llm.chat(messages)

# %%
print(resp)
# Out:
# assistant: Arrr, shiver me timbers! Ye be askin' about the big fella upstairs, eh? Well, matey, I've had me share o' dealin's with the divine, and I'll tell ye what I think.
#
# God, to me, be the great sea o' possibilities. It be the wind in me hair, the sun on me face, and the rum in me belly. It be the mystery o' the deep, the treasure hidden beneath the waves, and the adventure that lies ahead.
#
# But, I be a pirate, not a preacher! I don't be bound by no rules or dogma. Me god be a free spirit, a rebel, a swashbuckler o' the cosmos! Me god be the one who says, "Shiver me timbers! Let's set sail fer the unknown and see what treasures we can find!"
#
# Now, I know what ye be thinkin', "Pirate, that be a mighty strange notion o' god!" And ye be right, matey! But, I be a strange bird, even among me own crew. I be a pirate who's seen the beauty o' a sunset on the high seas, who's felt the rush o' battle, and who's heard the whispers o' the mermaids in the darkness.
#
# ...

# %%
response=llm.stream_complete("Explain the importance of low latencyLLMs")

# %%
 for r in response:
  print(r.delta,end="")
# Out:
# Low-latency Large Language Models (LLMs) are crucial in various applications where real-time or near-real-time processing is essential. Here are some reasons why low latency is important in LLMs:
#
# 1. **Interactive Systems**: In interactive systems like chatbots, virtual assistants, or conversational AI, low latency is vital to provide a seamless user experience. Users expect quick responses to their queries, and high latency can lead to frustration and abandonment.
# 2. **Real-time Decision Making**: In applications like autonomous vehicles, robotics, or healthcare, LLMs need to process and respond to data in real-time to make critical decisions. High latency can lead to accidents, misdiagnosis, or other severe consequences.
# ...

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="What is your name"),
]
resp = llm.stream_chat(messages)

# %%
for r in resp:
    print(r.delta, end="")
# Out:
# Arrr, me hearty! Me name be Captain Zephyr "Blackheart" McSnively, the most feared and infamous pirate to ever sail the Seven Seas! Me reputation precedes me, and me legend grows with each passing day. Me ship, the "Maverick's Revenge," be the fastest and most feared vessel on the high seas, crewed by the scurviest dogs and most cunning scallywags to ever hoist the Jolly Roger.
#
# But don't ye be thinkin' I be all about plunderin' and pillagin', matey! Oh no, I be a pirate of refinement and culture, with a taste for fine silks, exotic spices, and the finest grog this side of the Caribbean. Me trusty parrot, Polly, be perched on me shoulder, and me loyal first mate, Barnaby Blackbeak, be by me side at all times.
#
# So, what be bringin' ye to these fair waters, matey? Are ye lookin' to join me crew and seek yer fortune on the high seas? Or be ye lookin' to cross swords with the greatest pirate that ever lived? Either way, ye be in for a swashbucklin' adventure like no other!

# %%
pip install llama-index llama-index-embeddings-huggingface llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 88.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import logging
import sys
from google.colab import userdata
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.llms.openai import OpenAI
from llama_index.llms.groq import Groq

# %%
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# !mkdir data
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# --2025-03-13 07:57:58--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.003s
#
# 2025-03-13 07:57:59 (26.0 MB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
GROQ_API_KEY = "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"

# %%
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# llm = OpenAI(
#     model="gpt-3.5-turbo",
#     api_key=userdata.get('sk-o60aCUo7BIVicqzB9moWRGmmqi1cipD_DxNfLgYvdRT3BlbkFJBEdMcAOAsfbQoVnuEbEMDBjEm8WMrz16hteNIyjqUA')
# )

llm = Groq(
   model="llama3-70b-8192",
   api_key="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"
)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine=index.as_query_engine()

# %%
response=query_engine.query("What is doc about?")
print(response)
# Out:
# The document is about the author's personal experiences and reflections on their life, including their early interests in writing and programming, their college years, and their career in technology and entrepreneurship.
